# %% [markdown]
# # Vector space
# Subspace
# Span
# Null space
# Column and row space

# %% [markdown]
# # Subspace
# non-empty Set **S** of vector in R^n.
#
#
# if v, w belong to **S**,
#
#     v+w should belog to **S**,
#
#     cv as well in **S**
#
# then that is the subspace of set **S**.
#
# 0 은 항상 subspace에 속한다. subspace는 항상 0 벡터를 포함 (cv 에서 c = 0 이면 영벡터이므로)

# %% [markdown]
# # Span

# %% [markdown]
# # Null space

# %% [markdown]
# # Independence
